# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # Q1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#command to run chrome
driver = webdriver.Chrome(r'chromedriver.exe')

#get driver to visit defined URL
driver.get('https://amazon.in')
time.sleep(2)

# Taking input from user about product search
User_input=input('Enter the title of Product you are interest in search :')
# Out:
# Enter the title of Product you are interest in search :guitar

# %%
#input command in search bar
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')

#clearing any previous input in search bar
search.clear()

#feeding input specified by user to search menu through send keys
search.send_keys(User_input)

#finding Search button for clicking through xpath
search_button=driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]')

#clicking search button
search_button.click()

# %% [markdown]
# # Q2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
b_name=[]
product_name=[]
rating=[]
no_of_rating=[]
price=[]
ret_exchange=[]
exp_delivery=[]
availability=[]
other_details=[]
product_url=[]
urls=[]

# %%
for i in range(0,3):
    if i>2:
        break
    p_urls=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in p_urls:
        urls.append(i.get_attribute('href'))


    for i in urls:
        driver.get(i)
        time.sleep(2)
    #scraping data for brand name
        try:
            bran=driver.find_element(By.XPATH,"//a[@id='bylineInfo']")
            b_name.append(bran.text)
        except NoSuchElementException as e:
            b_name.append("--")

        #scraping data for product name
        try:
            prod=driver.find_element(By.XPATH,"//h1[@id='title']/span")
            product_name.append(prod.text)
        except NoSuchElementException as e:
            product_name.append("--")

        #scraping data for rating
        try:
            rat=driver.find_element(By.XPATH,"//span[@id='acrPopover']/span/a/i/span")
            rating.append(rat.text)
        except NoSuchElementException as e:
            rating.append("--")

        #scraping data for rating no.
        try:
            rat_no=driver.find_element(By.XPATH,"//span[@id='acrCustomerReviewText']")
            no_of_rating.append(rat_no.text)
        except NoSuchElementException as e:
            no_of_rating.append("--")

        #scraping data for price
        try:
            pri=driver.find_element(By.XPATH,"//div[@id='apex_desktop']/div/div/table/tbody/tr[2]/td[2]/span/span[2]")
            price.append(pri.text)
        except NoSuchElementException as e:
            price.append("--")

            #scaping data for return
        try:
            retu=driver.find_element(By.XPATH,"//div[@id='RETURNS_POLICY']/span/div[2]/a")
            ret_exchange.append(retu.text)
        except NoSuchElementException as e:
            ret_exchange.append("--")

        #scraping data for expected delivery
        try:
            deliv=driver.find_element(By.XPATH,"//div[@id='ddmDeliveryMessage']/b")
            exp_delivery.append(deliv.text)
        except NoSuchElementException as e:
            exp_delivery.append("--")

        #scraping data for availability
        try:
            avail=driver.find_element(By.XPATH,"//div[@id='availability']/span")
            availability.append(avail.text)
        except NoSuchElementException as e:
            availability.append("--")

        #scraping data for other details
        try:
            od=driver.find_element(By.XPATH,"//div[@id='feature-bullets']/ul/li/span")
            other_details.append(od.text)
        except NoSuchElementException as e:
            other_details.append("--")
     
    # selecting and clicking next page
    try:
        if i==1:
            n_button=driver.find_element(By.XPATH,"//div[@class='a-section a-spacing-none a-padding-base']/div/ul/li[3]/a")
            n_url=n_button.get_attribute('href')
            driver.get(n_url)
            time.sleep(2)
    except:
        if i==2:
            n_button=driver.find_element(By.XPATH,"//div[@class='a-section a-spacing-none a-padding-base']/div/ul/li[4]/a")
            n_url=n_button.get_attribute('href')
            driver.get(n_url)

# %% [markdown]
# # Q3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe")

# Getting the webpage of mentioned url 
url = "https://images.google.com/"

#Creating empty list 
urls = []   
data = []    
search_item = ["fruits", "cars", "Machine Learning", "Guitar", "Cakes"]
for item in search_item:
    driver.get(url)  
    time.sleep(5)
    
    # Finding webelement for search_bar
    search_bar = driver.find_element(By.TAG_NAME,"input") 
    
    # Sending keys to get the keyword for search bar
    search_bar.send_keys(str(item))
    
    # Clicking on search button
    search_button = driver.find_element(By.XPATH,'//button[@class="Tg7LZd"]').click()
    
    # Scrolling down the webpage to get some more images
    for _ in range(50):
        driver.execute_script("window.scrollBy(0,100)")
        
        imgs = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
    img_url = []
    for image in imgs:
        source = image.get_attribute('src')
        if source is not None:
                if(source[0:4] == 'http'):
                    img_url.append(source)
    for i in img_url[:10]:
        urls.append(i)
                    
for i in range(len(urls)):
    if i >= 50:
        break
    print("Downloading {0} of {1} images" .format(i, 50))
    response = requests.get(urls[i])
    file = open(r"C:\Users\AnandRaj\Downloads\fliprobo googlepics"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# Downloading 0 of 50 images
# Downloading 1 of 50 images
# Downloading 2 of 50 images
# Downloading 3 of 50 images
# Downloading 4 of 50 images
# Downloading 5 of 50 images
# Downloading 6 of 50 images
# Downloading 7 of 50 images
# Downloading 8 of 50 images
# Downloading 9 of 50 images
# Downloading 10 of 50 images
# Downloading 11 of 50 images
# Downloading 12 of 50 images
# Downloading 13 of 50 images
# Downloading 14 of 50 images
# Downloading 15 of 50 images
# Downloading 16 of 50 images
# Downloading 17 of 50 images
# Downloading 18 of 50 images
# Downloading 19 of 50 images
# Downloading 20 of 50 images
# Downloading 21 of 50 images
# Downloading 22 of 50 images
# Downloading 23 of 50 images
# Downloading 24 of 50 images
# Downloading 25 of 50 images
# Downloading 26 of 50 images
# Downloading 27 of 50 images
# Downloading 28 of 50 images
# Downloading 29 of 50 images
# Downloading 30 of 50 images
# Downloading 31 of 50 images
# Downloading 32 of 50 images
# Downloading 33 of 50 images
# Downloading 34 of 50 images
# Downloading 35 of 50 images
# Downloading 36 of 50 images
# Downloading 37 of 50 images
# Downloading 38 of 50 images
# Downloading 39 of 50 images
# Downloading 40 of 50 images
# Downloading 41 of 50 images
# Downloading 42 of 50 images
# Downloading 43 of 50 images
# Downloading 44 of 50 images
# Downloading 45 of 50 images
# Downloading 46 of 50 images
# Downloading 47 of 50 images
# Downloading 48 of 50 images
# Downloading 49 of 50 images

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="0b957e0bc8fec9ffb3e16d9232543ed3")>>

# %% [markdown]
# # Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be
# scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,
# “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the
# details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe")

url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(3)

# %%
driver.find_element(By.XPATH,"//button[@class='_2KpZ6l _2doB4z']").click()

# %%
# to enter the item name which user wants to search
item = input(" Enter the name of Smartphone that has to be searched : ")

#giving input key word to search bar
serch_bar = driver.find_element(By.XPATH,"//div[@class='_3OO5Xc']//input")
serch_bar.send_keys(item)

# to click search button
srch_btn = driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
srch_btn.click()
time.sleep(5)
# Out:
#  Enter the name of Smartphone that has to be searched : OnePlus Nord

# %%
page1_urls = []
urls = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for url in urls:
    page1_urls.append(url.get_attribute("href"))

# %%
len(page1_urls)
# Out:
# 24

# %%
Smartphones = {}
Smartphones["Brand"] = []
Smartphones["Phone name"] = []
Smartphones["Colour"] = []
Smartphones["RAM"] = []
Smartphones["Storage(ROM)"] = []
Smartphones["Primary Camera"] = []
Smartphones["Display Size"] = []
Smartphones["Battery Capacity"] = []
Smartphones["Price"] = []
Smartphones["URL"] = []

# %%
# Scraping data from each url of page 1
for url in page1_urls:
    driver.get(url)                                                        
    print("Scraping URL = ", url)
    Smartphones['URL'].append(url)                                                          
    time.sleep(2)
    
    
    #Clicking on read more button
    try:
        read_more = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')     
        read_more.click()
    except NoSuchElementException:
        print("Exception occured while moving to next page")
    
    
    #Scraping brand name of phone data
    try:
        brand_tags = driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')      
        Smartphones["Brand"].append(brand_tags.text.split()[0])
    except NoSuchElementException:
        Smartphones['Brand'].append('-')
    
    
    #Scraping phone name data
    try:
        name_tags = driver.find_element(By.XPATH,'//li[@class="_21lJbe"]')     
        Smartphones['Phone name'].append(name_tags.text)
    except NoSuchElementException:
        Smartphones['Phone name'].append('-')
    
    
    #Scraping phone color data
    try:
        color_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')      
        Smartphones['Colour'].append(color_tags.text)
    except NoSuchElementException:
        Smartphones['Colour'].append('-')
        
      #Scraping RAM data
    try:
        ram_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[2]/td[2]/ul/li')                
        Smartphones['RAM'].append(ram_tags.text)
    except NoSuchElementException:
        Smartphones['RAM'].append('-')
    
    
    #Scraping ROM data
    try:
        rom_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table[1]/tbody/tr[1]/td[2]/ul/li')        
        Smartphones['Storage(ROM)'].append(rom_tags.text)
    except NoSuchElementException:
        Smartphones['Storage(ROM)'].append('-')
        
            
    #Scraping Primary camera data
    try:                                                                                    
        pri_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table[1]/tbody/tr[2]/td[2]/ul/li')
        Smartphones['Primary Camera'].append(pri_tags.text)
    except NoSuchElementException:
        Smartphones['Primary Camera'].append('-')
        
   
    #Scraping Display size data 
    try:
        disp_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/div')
        if disp_tags.text != "Display Features" : raise NoSuchElementException
        disp_size = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table[1]/tbody/tr[1]/td[2]/ul/li')  
        Smartphones['Display Size'].append(disp_size.text)
    except NoSuchElementException:
        Smartphones['Display Size'].append('-')
     

    
    #Scraping battery capacity data
    try:
        if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/div').text != "Battery & Power Features" :
            if driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][9]/table/tbody/tr/td[2]/ul/li')                
            elif driver.find_element_by_xpath('//div[@class="_3k-BhJ"][8]/div').text == "Battery & Power Features" :
                bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[1]')
                if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
                bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][8]/table/tbody/tr/td[2]/ul/li')
            else:
                raise NoSuchElementException
        else :
            bat_tags = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[1]')
            if bat_tags.text != "Battery Capacity" : raise NoSuchElementException
            bat_capa = driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][10]/table/tbody/tr/td[2]/ul/li')              
        Smartphones['Battery Capacity'].append(bat_capa.text)
    except NoSuchElementException:
        Smartphones['Battery Capacity'].append('-')
# Scraping URL =  https://www.flipkart.com/oneplus-nord-2t-5g-jade-fog-256-gb/p/itm97eda8b1a1566?pid=MOBGHHYHNZBQBPZY&lid=LSTMOBGHHYHNZBQBPZYUWDDFR&marketplace=FLIPKART&q=OnePlus+Nord&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=75b96065-b400-4d05-8963-938643b83b23.MOBGHHYHNZBQBPZY.SEARCH&ppt=hp&ppn=homepage&ssid=jbfhcvfxuo0000001663739438772&qH=affdc902290cef81

# %%
print(len(Smartphones["Brand"]), len(Smartphones["Phone name"]), len(Smartphones["Colour"]), len(Smartphones["RAM"]), len(Smartphones["Storage(ROM)"]))
# Out:
# 24 24 24 24 24

# %%
df = pd.DataFrame.from_dict(Smartphones)
df
# Out:
#       Brand                                         Phone name        Colour  \
# 0   OnePlus  Phone,SIM Tray Ejector, Adapter, Phone Case, U...     Blue Tide
# 1   OnePlus  Phone,SIM Tray Ejector, Adapter, Phone Case, U...     Blue Tide
# 2   OnePlus  Phone,SIM Tray Ejector, Adapter, Phone Case, U...    Black Dusk
# 3   OnePlus  Handset,SIM Tray Ejector, Adapter, Phone Case,...    Black Dusk
# 4   OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...      Jade Fog
# 5   OnePlus  Phone,SIM Tray Ejector, Adapter, Phone Case, U...    Black Dusk
# 6   OnePlus  Handset,SIM Tray Ejector, Adapter, Phone Case,...     Blue Tide
# 7   OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...   Gray Shadow
# 8   OnePlus  Phone,SIM Tray Ejector, Adapter, Phone Case, U...     Blue Tide
# 9   OnePlus  Handset,SIM Tray Ejector, Adapter, Phone Case,...    Black Dusk
# 10  OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...   Gray Shadow
# 11  OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...      Jade Fog
# 12  OnePlus  Handset,Warp Charge 30T power adapter Warp Typ...  Charcoal Ink
# 13  OnePlus  Screen protector (pre-applied), Warp Charge 30...   Blue Marble
# 14  OnePlus  Screen protector (pre-applied), Warp Charge 30...     Gray Onyx
# 15  OnePlus  Screen protector (pre-applied), Warp Charge 30...     Gray Onyx
# 16  OnePlus  Screen protector (pre-applied), Warp Charge 30...   Blue Marble
# 17  OnePlus  Screen protector (pre-applied), Warp Charge 30...   Blue Marble
# 18  OnePlus  Screen protector (pre-applied), Warp Charge 30...     Gray Onyx
# 19  OnePlus  Handset , 65W SUPERVOOC power adapter, Cable (...   Gray Mirror
# 20  OnePlus  Handset , 65W SUPERVOOC power adapter::Cable (...   Bahama Blue
# 21  OnePlus  Handset,Warp Charge 65 power adapter, Warp Typ...   Gray Sierra
# 22  OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...      Jade Fog
# 23  OnePlus  Mobile, Adapter, Phone Case, SIM Tray Ejector,...      Jade Fog
# 6   https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 7   https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 8   https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 9   https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 10  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 11  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 12  https://www.flipkart.com/oneplus-nord-ce-5g-ch...
# 13  https://www.flipkart.com/oneplus-nord-blue-mar...
# 14  https://www.flipkart.com/oneplus-nord-gray-ony...
# 15  https://www.flipkart.com/oneplus-nord-gray-ony...
# 16  https://www.flipkart.com/oneplus-nord-blue-mar...
# 17  https://www.flipkart.com/oneplus-nord-blue-mar...
# 18  https://www.flipkart.com/oneplus-nord-gray-ony...
# 19  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 20  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 21  https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 22  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 23  https://www.flipkart.com/oneplus-nord-2t-5g-ja...

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="4524b86264168cef4b9720e57aebd7b7")>>

# %% [markdown]
# # Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps

# %%
# to get web browser
driver=webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe") 
time.sleep(2)

# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


#Sending keyword for seach bar and search button
city = input('Enter City name that has to be searched : ')
search_bar = driver.find_element(By.ID,"searchboxinput")                       
search_bar.clear()                                                             
time.sleep(2)
search_bar.send_keys(city)                                                     
search_btn = driver.find_element(By.ID,"searchbox-searchbutton")              
search_btn.click()                                                             
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# Enter City name that has to be searched : Hyderabad
# URL Extracted:  https://www.google.co.in/maps/place/Hyderabad,+Telangana/@17.5082583,78.4638163,15z/data=!4m5!3m4!1s0x3bcb99daeaebd2c7:0xae93b78392bafbc2!8m2!3d17.385044!4d78.486671
# Latitude = 17.5082583, Longitude = 78.4638163

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="928d4238309a907ddee85103bf342e9a")>>

# %% [markdown]
# # Q6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
driver=webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe") 
time.sleep(2)

#to get url
driver.get('https://trak.in/')

#to get xpath for funding deals
fund_button = driver.find_element(By.XPATH,'//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(fund_button)

# %%
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

# %%
for i in range(54,57):
    # Date
    dt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
      # Investor
    inv = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)

# %%
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
#           Date            Startup Name       Industry/Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#    Amount(in USD)
# 0     1,80,00,000
# 1    6,172,258.50
# 2      30,000,000
# 3      15,000,000
# 4      16,000,000
# 5      15,000,000
# 6     100,000,000
# 7       4,000,000
# 8       2,500,000
# 9     250,000,000
# 10   2,747,045.20
# 11    1,50,00,000
# 12     75,000,000
# 13      4,773,958
# 14     55,000,000
# 15     15,000,000
# 16     18,000,000
# 17    250,000,000
# 18    140,000,000
# 19      8,000,000
# 20    460,000,000
# 21    300,000,000
# 22     11,000,000
# 23     27,500,000

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="0650c68b5a9842f5a0e6f011a9ee6370")>>

# %% [markdown]
# # Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
url = "https://www.digit.in/"
driver.get(url)
time.sleep(2)

# %%
best_gam_laptops = driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# %%
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Graph_proc = []
Price = []

# %%
# Scraping the data of laptop names
laptop_name= driver.find_elements(By.XPATH,"//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memory = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass

#Scraping data of weight
try:
    weight = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for wgt in weight:
        Weight.append(wgt.text)
except NoSuchElementException:
    pass

#Scraping data of dimensions
try:
    dimension = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of Graph processor
try:
    graph = driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
    for gra in graph:
        Graph_proc.append(gra.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    price = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),len(Operating_sys),len(Display),len(Processor),len(Memory),len(Weight),len(Dimensions),len(Graph_proc),len(Price))
# Out:
# 0 10 10 10 10 10 10 10 10

# %%
data=list(zip(Laptop_Name, Operating_sys, Display, Processor, Memory, Weight, Dimensions, Graph_proc, Price))

# %%
df=pd.DataFrame(data,columns=['Laptop_Name','Operating_System','Display','Processor','Memory','Weight','Dimension','Graph_Proc','Price'])
df
# Out:
# Empty DataFrame
# Columns: [Laptop_Name, Operating_System, Display, Processor, Memory, Weight, Dimension, Graph_Proc, Price]
# Index: []

# %% [markdown]
# # Q8. Write a python program to scrape the details for all billionaires from www.forbes.com.
# Details to be
# scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver=webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe")

#Getting the specified url
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(3)

# %%
button = driver.find_element(By.XPATH,'//div[@class="_69hVhdY4"]')
button.click()
time.sleep(1)

# %%
bill = driver.find_element(By.XPATH,'//li[@class="TjJgrPSg cD45ib6e primary"]')
bill.click()
time.sleep(1)

# %%
world_bill= driver.find_element(By.XPATH,'//li[@class="TjJgrPSg _2bNo56RE secondary"]')
world_bill.click()
time.sleep(1)

# %%
#Creatng empty lists
Rank = []
Person_Name = []
total_net_worth = []
Age = []
citizenship = []
Source = []
industry = []

# %%
while(True):
    #Scraping the data of rank of the billionaires
    rank_tags= driver.find_elements(By.XPATH,'//div[@class="rank"]')
    for rank in rank_tags:
        Rank.append(rank.text)
    time.sleep(1)
    
    
    #Scraping the data of names of the billionaires
    name_tags= driver.find_elements(By.XPATH,'//div[@class="personName"]/div')
    for name in name_tags:
        Person_Name.append(name.text)
    time.sleep(1)
    
    
    #Scraping data of age of the billionaires
    age_tags= driver.find_elements(By.XPATH,'//div[@class="age"]/div')
    for age in age_tags:
        Age.append(age.text)   
    time.sleep(1)
    
    
    #Scraping data of citizenship of the billionaires
    cit_tags= driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
    for cit in cit_tags:
        citizenship.append(cit.text)
    time.sleep(1)
    
    
    #Scraping data of source of income of the billionaires
    sour_tags= driver.find_elements(By.XPATH,'//div[@class="source"]')
    for sour in sour_tags:
        Source.append(sour.text)    
    time.sleep(1)
    
    
    #Scraping data of Industry of the billionaires
    ind_tags= driver.find_elements(By.XPATH,'//div[@class="category"]//div')
    for ind in ind_tags:
        industry.append(ind.text)
        
    
    #scraping data of net_worth of billionaires
    net_tags= driver.find_elements(By.XPATH,'//div[@class="netWorth"]//div[1]')
    for net in net_tags:
        total_net_worth.append(net.text)
    time.sleep(1)
    
    #Clicking on next button
    try:
        next_button = driver.find_element(By.XPATH,"//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break
        
#Scraping data of net worth
Net_Worth = []
for i in range(0,len(total_net_worth),2):
    Net_Worth.append(total_net_worth[i])

# %%
Billionaires=pd.DataFrame({})
Billionaires['Rank'] = Rank
Billionaires['Names'] = Person_Name
Billionaires['Net Worth'] = Net_Worth
Billionaires['Age'] = Age
Billionaires['Citizenship'] = citizenship
Billionaires['Source'] = Source
Billionaires['Industry'] = industry
Billionaires
# Out:
#        Rank                     Names Net Worth Age    Citizenship  \
# 0        1.                 Elon Musk    $219 B      United States
# 1        2.                Jeff Bezos    $171 B      United States
# 2        3.  Bernard Arnault & family    $158 B             France
# 3        4.                Bill Gates    $129 B      United States
# 4        5.            Warren Buffett    $118 B      United States
# ...     ...                       ...       ...  ..            ...
# 2663  2578.             Zhang Yuqiang      $1 B  66          China
# 2664  2578.                Zhou Ruxin      $1 B  59          China
# 2665  2578.         Wen Zhou & family      $1 B  57          China
# 2666  2578.      Zhou Yifeng & family      $1 B  43          China
# 2667  2578.   Zhuang Kuilong & family      $1 B  59          China
#
#                        Source       Industry
# 0               Tesla, SpaceX
# 1                      Amazon
# 2                        LVMH
# 3                   Microsoft
# 4          Berkshire Hathaway
# ...                       ...            ...
# 2663               Fiberglass  Manufacturing
# 2664               Navigation     Technology
# 2665                chemicals  Manufacturing
# 2666  liquefied petroleum gas         Energy
# 2667                polyester  Manufacturing
#
# [2668 rows x 7 columns]

# %%
Billionaires.to_csv("Forbes_Billionaries.csv")

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="34fd46b8512b179d2356e69b84cd2dfa")>>

# %% [markdown]
# # Q9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver=webdriver.Chrome(r"C:\Users\AnandRaj\Downloads\internship\chromedriver.exe") 
time.sleep(2)

url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

# %%
user_input = input('Enter the video you want to search : ')

#finding element for search bar
search_bar = driver.find_element(By.XPATH,'//input[@id="search"]')
search_bar.send_keys(user_input)
time.sleep(1)
# Out:
# Enter the video you want to search : Sidemen : WHO IS THE BEST SIDEMEN FOOTBALL PLAYER?

# %%
search_btn = driver.find_element(By.ID,"search-icon-legacy")  
search_btn.click()
time.sleep(1)

# %%
link_click = driver.find_element(By.XPATH,"//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link_click.click()

for _ in range(10000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# to scrape comments
cm_tags = driver.find_elements(By.ID,"content-text")
for cm in cm_tags:
    if cm.text is None:
        comments.append("--")
    else:
        comments.append(cm.text)
time.sleep(5)
comments[:500]
# Out:
# ['Pie looks incredible and I love that man',
#  'Vik is so humble he didn’t show his true powers so the others wouldn’t be humiliated',
#  'Vik is so down to Earth. He thought he’d go ez mode on these scrubs to give them a chance. What a hero',
#  'Manny seems to be so much more confident and lively in front of camera and well done pieface for the crazy weightloss. Both Sidemen and associates are inspiring through the roof. Much love to all',
#  'Nothing hits more than a cold Sunday watching sidemen wrapped up warm with a hot drink good vibes. Can’t wait for the match',
#  'The fact that VIK blessed this video with his football god presence, such a giving man',
#  "Vik is such a humble guy. He didn't show his true punjabi powers as it would intimidate the boys.",
#  'Every week it feels like the sidemen Sundays are coming quicker ',
#  '“Why is he jogging like that?”\n“It’s what he does outside schools” ',
#  'crying cause its just like the old days. these will always be my favorite type of videos',
#  'Its so wholesome how Josh helps and trys to support vik at the Freekicks',
#  "39:57 The transition, the music kicking in, the edit, the shot and the reaction of the boys made this moment one of the best one i've seen in a while, what a masterpiece.",
#  'Pie looks unbelievable, well done mate.',
#  "I can't lie, this might be the best Sidemen Charity Match ever",
#  'Simon’s happiness when playing football is so wholesome',
#  'It makes me laugh how from one minute to the next Harry and Simon are best friends and then enemies',
#  '37:17 theo mocking chris "someone jealous? someone jealous?" is sooo hilarious',
#  'I like how Vik went easy on these noobs. What a great guy.',
#  'Gotta say the editor for this 10/10 the editing for 24:30 had me crying Felix Baumgartner falling LOOL',
#  'About time we had a new football video from the lads, preparation for the Charity Match as well!  Loved the edits in this as well. ',
#  'World needs more people like Tobi. I had no idea Manny is his brother. World is a better place with them lot',
#  "never thought I'd see the day Vik missed a pen",
#  '13:18 is such a beautiful moment. I replayed it like 5 times',
#  'Nothing to make your sunday better than sidemen posting',
#  "Why's Simon and Chris Md not actually just make a video legitimately trying to coach vik to kick a ball",
#  'this is giving me old sidemen penalty shootout man, such a nostalgic feeling',
#  'I can’t wait until JJ does 5 Sidemen Sundays on his own to catch up ',
#  'Simon is one of the best free kick takers in the world',
#  'People love how Tobi and Josh were just there standing around like Ant and Dec.',
#  'Mad respect to Pie Face for that amazing transformation. Incredible.',
#  'Harry anf Behz just showing up with a pint is just incredibly on character',
#  'Pie looks amazing so proud of him what a top guy',
#  'Tobi saying “that’s my brother” actually is so cute ',
#  '“Declan too much rice”\nGot me dying ',
#  'I’d honestly love to see more driving videos. These are awesome too but the driving videos are amazing. Love your guys’ content though! <3',
#  "All jokes aside, I love how supportive they are of Vik even though football's clearly not his thing.",
#  "31:56 Theo hit both targets, but it didn't go in. That is special talent.\nSimon being a weirdo, like in every football video, because no normal person does that",
#  "33:17\nEthan: I ate the floor on that\nCallux: I'm not surprised ",
#  'Vik has gotten really good he just needs to learn how to aim it',
#  'Vik staying humble to up the confidence of his teammates. He will show his true self in the real match.',
#  '28:10 the sight of Harry dancing never fails to amuse me ',
#  'Love how Tobi and Josh were just there standing around like Ant and Dec.',
#  'Brings back all the golden days memory, especially the celebration after Manny great touch.',
#  'The live audience makes the video so much more entertaining ',
#  'The editing on this is phenomenal ',
#  "Big G, for Vik, he knows he's not at football but he never flinches to try ️",
#  '"People aren\'t expecting great things from me, so I\'m not giving them great things." - Callum Aaron McGinley.',
#  'Behz lifting his shirt and running to the stands had me dying ',
#  'Simons actually underated at football! Every football video he is amazing ',
#  '32:18 are we all gonna skip Cal’s comment.\nEthan says “I ate the floor on that”\nCal says “I’m not surprised”\nBro I died ',
#  'Shout out to pie Hes done so well in his weight loss journey he looks so good congratulations Pie ',
#  'Pie’s weight loss is unbelievable, What a legend ',
#  "The excited 'that's my brother' from Tobi was so lovely",
#  '34:29 that LeBron "silencer" celebration',
#  '25:43 had me gasping for air. the Scott Sterling audio clip did it for me',
#  'more videos like this, please. throwback to the good old days.',
#  'I love how all audiences are showing their love',
#  'Josh hit Simon with the crutch like the meme lol ',
#  "Everyone seemed ace and some of the shots were peak. can't wait for this rumble of a match.\nand may the odds forever be in sidemen favor",
#  'It has been a long time since we have seen a Football Sidemen Sunday. I really enjoyed that !',
#  '“Let’s see how their cards look at the end”\n\nLiterally shows it for .5 seconds ',
#  '“Now all the challenges are done let’s see how their stats look at the end” The flash enters the chat',
#  'When I watch these videos, I respect every time Vik shows up.',
#  "Never seen any of Pies content but from this video he seems like an awesome guy can't wait to watch the charity match",
#  "So proud of Pie, man's looking great!\n\nExcited to see the match at the end of this month :)",
#  'Not seeing many comments about how incredible pie face looks? Looks like a different human being all together, congrats to him.',
#  'Harry has a pint everywhere man, even on a football pitch ',
#  "49:00 look at Ethan's hand\nHe even take a sniff after that",
#  'The memes here are top notch \nShout out to the editor, smashed it ',
#  "44:43 Simon saying what I've been thinking this whole video :')",
#  'They should have a reaction camera same time they shoot the ball.',
#  "Toby is really nice but he's still a brother, the way he told the people to boo Manny ",
#  "I like how the editors took Bakers reaction to Simons free kick and put it in the build up to Chris's free kick... Nice touch lads",
#  'Vik is such a nice guy. He didn’t show his Cajun powers in this soccer match',
#  "Can't wait for Sidemen Charity Match. ",
#  '"It\'s Declan too much Rice"',
#  'I actually don’t understand how vik hasn’t learnt how to hit the ball after 5 years',
#  "When Theo hit the post from one inch away..... I haven't laughed that much since Theo's last appearance in blind date. Put the man in more videos!",
#  'Sidemen Sundays always make the day perfect  !!',
#  'Pie face in goal. Sideman deffo aren’t trying to win this year ',
#  'Tobi: drops the ball\nManny: kicks it \nTobi: Thats my brother ',
#  'Pie’s Weight loss journey is incredible, props to him ',
#  'Great vid. we need more, had me laughing',
#  '32:19 Ethan: “I ate the floor on that”\nCallux: “I’m not surprised”\n\nCallux was hilarious in this video ',
#  'I look forward to sidemen Sunday every week! Now to wait for the next one ',
#  'Loved finally seeing a football video again ',
#  'Theo is the best youtube footballer hands down. Impressive through and through. Hair though..',
#  'Manny: does a godly touch\nTobi: “that’s my brother”\n\nSo Wholesome',
#  'Amazing video as usual guys , your videos always make my day , thanks very much , keep making people smile  , I love the positive vibes , keep them coming !!',
#  'O tanto que o Simon representou os brasileiros ',
#  'this really shows that taking shots in a video vs in a real match is madly different',
#  '13:22 reminded me of old Sidemen. This is why I started watching their content.',
#  'Sidemen soccer videos bring back so much great nostalgia ',
#  'This video had me laughing the whole way through Harry shouting “it’s on the wrong side” priceless ',
#  "Could we get a heat-map of Pie's movement please ",
#  "'Declan too much rice' had me dying ",
#  '"Declan ate too much rice" probably the most hilarious thing i heard today. ',
#  'This feels more like an " MoreSidemen " video than a " SidemenSunday " video.',
#  'We need a new strength tetst as a sidemen sunday soon',
#  "Manny's ball control was just filthy. A lot of Premier League footballers have failed that challenge",
#  '“Better distribution than Amazon” had me rolling ',
#  '"People aren\'t expecting great things from me, so i\'m not giving them great things." -Callux',
#  'Manny is so talented at football its literally ridiculous, its like watching an artist',
#  'Manny’s touch was too sick that angle was mad ',
#  'Can we just appreciate the editing on this video!',
#  '25:44 the way his leg wobble like a goofy cartoon character is just beyond funny, I am crying ',
#  'watching sidemen at night with the late night snack. wrapped up. it hits different. :)',
#  'Harry giving it back was funny af',
#  "Theo is quick af , without his stomach he'll definitely be first",
#  'viks a really nice guy, played bad infront of his friends to keep the peace',
#  'Vik is Soo inspirational man, he could have used his Punjabi sause to body these merchants but he choose to stay humble ',
#  'No other way to start my week better than sidemen Sunday and Harry showing middle finger',
#  "I don't really like videos on YouTube, but that control touch by Manny was so insane that I just remembered that I had to SMASH that like button.",
#  "Ethan has been inform lately. He's scoring this time around.",
#  'Editing is on point in this video ',
#  'That Simon celebration though ',
#  'I think we all been wanting an OG football vid and we all secretly jumping for joy inside idk maybe it’s just me',
#  "Honestly looking forward to see vik play again. I reckon he's improved a lot more",
#  'Finally a sidemen Sunday football video. Been waiting for this for too long',
#  'That first ball control from Manny was so ',
#  '21.40 “declan to much rice” ',
#  'I love the football vids and holiday vids keep ip the good work',
#  'I love how humble vik is',
#  'Whoever edited this had way too much fun ',
#  'Those free kicks from Simon were actually cold',
#  "Watching some of these man kick ball acc makes me think I'm way better than I am looooolall jokes aside tho watching this makes me so eager to get started playing 6-a-side at uni again man it’s been a long summer without it n now I can’t wait",
#  'Vik’s beef with the mannequins was the best part of the video ',
#  'They are the most average guys ever !! \n\nAnd thats why we love them!',
#  'Vikk might not be as good in this video but he is gonna be way better in the charity match (hopefully) ',
#  "This video is literally just Chris's video... AND I LOVE IT!!!! Banger guys!!!",
#  'The Roy Keane memes for Pie absolutely killed me ',
#  '27:40 the goal keeper cut scene, funny af ',
#  '33:10 I dont think Vikk realises how sick that goal is',
#  'Does Ethan have crabs he’s always scratching his nuts ',
#  'After the goalkeeping perfomance I can see the sidemen conceding 20 goals',
#  'when Harry runs straight out to congratulate callux ',
#  'Pie looks amazing so proud of him man!',
#  'This charity match is going to be amazing.',
#  "13:20 Manny's touch on that ball was insane",
#  'I love all the audience’s insults they were way to funny',
#  'That cut from ronaldo to simon was so sick i had to rewind that ',
#  'Love the old school sidemen football vids',
#  'Bro i loved ur vids after yrs of football like all of them together bro its jus amazin missin jj tho he made it more funnier',
#  'The editing was great on this one',
#  'How does Vik have a higher stat than Lux on pens and he missed all 3 penalties? ',
#  'Can’t wait for the match next Saturday lads. Gonna bang ',
#  'Bahaha respect to pie for throwing himself in front this whole vid',
#  'Love the comment from Toby when he\'s in the cherry picker " that\'s my brother"',
#  'Need at least a single instant replay for the good tricks/shots',
#  '32:19 is literally the funniest part',
#  'It’s amazing how even when I’m at my lowest they manage to change my mood and put an smile on my face',
#  'Love the Roy Keane commentary, love the mad editing and traditions, love the old references. Just loved this video. Big up!',
#  'I truly believe if Minter had chosen football he would have made a fine player...',
#  'Man i would´v loved to see jj do the passing challenge. Last time he beat simon so who knows',
#  'Others: hold my beer\nW2S and behz:………',
#  "Don't ask me how or why i noticed this but Ethan can't stop playing with himself.  Either he is aroused by watching others kicking balls or he might have some infection. ",
#  'Theo and Chris claiming they can do anything at the level of professional footballers is embarrassing',
#  'I usually don’t care for “football” videos, but this one is banging!',
#  'Harry scoring that volley was iconic!!!',
#  'I love the new kind of editing and all the clips being added. Hilarious',
#  'Now that pie is in the charity match it will be legendary',
#  "Callux looked and he moved like an alien in this one!! Unfortunately his football abilities weren't out of this world though.",
#  'Pieface is such a nice guy, would love to see him feature more often :D',
#  "I love how Toby nd josh r literally being Vik's mom nd dad through the whole video... XD",
#  "Viks ankle blowing up was the best thing I've ever seen",
#  'I love how the crowd celebrates when the boys miss',
#  'Harry is cultured person. Love all the jersey he wore. Damn is art',
#  'I love the lads banter in videos like this something nostalgic and wholesome ️',
#  "Vik's touch has got soo much better, good contact with ball, he just needs to know how to place it",
#  '25:43 - that slow motion replay of vik ended me, his face man hahahaha',
#  'Can we take a minute to appreciate pies weight loss  incredible',
#  'KSI should react to vik and lux’s shooting skills  i would love to hear him laugh',
#  'The editors had a field day with pie',
#  'them throwing it back is the best ',
#  'Shoutout Chip fat. He banged the editing on this video! Hyped for the Charity Match!',
#  '39:52  \nThe shot, the music and the boys reaction, magical',
#  'I don’t know the full squad but from this vid and having JJ too I think the below formation:\n\nGK - Pieface\nRB - Ethan',
#  "Don't know what's more shocking, Chris making the first team or Pie saving Vik's penalties",
#  "Hate it when Toby doesn't participate... He is just too good tbh.",
#  'Why are Josh and Toby going around in crutches trying to keep their secrets for the actual game?',
#  'I bet vik is happy jj ain’t in this video, no one laughed at how bad he is ',
#  'I refuse to believe that vikk is this bad at kicking a ball after being around football vids for 10 years lmao ',
#  '31:53 the literal definition of hero to zero THEO!!',
#  'FINALLY A football challenge ',
#  'Vik’s foot: it went wiggle wiggle, it folds ',
#  'We down, Vik up  mans gonna carry after that pen connection',
#  'If pie is in goal they gonna concede 10 but he is a fun lad i want him to start',
#  'Vik is a priceless player making him the best overall. Nothing quite like viks touch',
#  'the shots to commentary on a goalkeeper which just fit perfectly with the actions of this goalkeeper',
#  'Theo Baker ist actually the best YouTube footballer and he’s really funny as well',
#  "I don't know why, but now that i've watched this ir really badly want someone to get a red card, just for the comedy live",
#  'finally a football video been waiting so long for another one',
#  'The way simon celebrated is so fing funny',
#  'Harry\'s volley from the " right side" can only be described by jj talking about how nicely Josh came to rap in the song Tommy t',
#  'Harry’s volley was class.',
#  'Nothing hits more than a cold Sunday watching sidemen wrapped up warm with a hot drink good vibes. Can’t wait for the match',
#  'Pie looks unbelievable, well done mate.',
#  "Vik is such a humble guy. He didn't show his true punjabi powers as it would intimidate the boys.",
#  "Honestly looking forward to see vik play again. I reckon he's improved a lot more",
#  "Honestly looking forward to see vik play again. I reckon he's improved a lot more",
#  '25:56 really got me… my brudda was crawlin like he’s in cod warzone waiting to be revived ️',
#  'Saw Harry at the Little National Hotel in Sydney two days ago, he walked into the elevator on level two as I was heading down my jaw dropped aye haha great to see him down under ',
#  'This SDMN sunday was really enjoyable',
#  'ChipFat is a legend ',
#  'Sidemen just can never disappoint. I always have a big smile on my face watching them',
#  'Please someone teach Vik the proper way to shoot a ball. He can really hurt himself.',
#  'Chris is such a tryhard, Simon is always so chill with it.',
#  "Bruh y'all  are Killin it! 2.4 mil views in 9 hours keep it up",
#  'Lets start a movement and try to move sidemen to rumble instead so they can be themselves without any fear',
#  '25:30 The ball boy questioning his life choices ',
#  '“lux kicks the ball in black and white” had me dying ',
#  'The edits in this were legendary',
#  'Manni is on a different level simon always sick but behz surprised me',
#  'For Harry’s touch they changed balls ️  must’ve messed up badly the first time ',
#  'That touch by Manny was INSANE',
#  'The crowd screams “I’m 28 and I go out with 16 year olds”',
#  'i lost it when theo took it past them pieface had the whole net and still missed. quality vid.',
#  'Viks been doing these sidemen football videos for ages now and somehow no one has managed to teach him how to kick a ball yet.',
#  'Mad respect to pie but seriously though I hope he’s not going to be the sidemen’s main keeper ',
#  'Don’t usually like Football videos but this has gotta be one of my favourites.',
#  'This is how the sidemen started years agoo ️️',
#  'Harry is the Definition of “Hold My Beer” ',
#  'Hope Toby gets well soon. We wanna see the sprints on that stadium boyy',
#  "Year 2016, Tobi hits the crossbar with a Trivela, I'm ready starts to play in the background.....",
#  "I'm actually so proud of Pie hes come so far <3",
#  '35:15 the eye turning from manny to josh',
#  'Vik nailed that ball drop, yet no love?!?! Wtf?',
#  '32:20\nBez- I ate the floor on that \nCallux- I’m not surprised ',
#  '11:20 vikstar saying ethan was probably best at penalties and at the same time ethan saying vik was worst at it had me dying',
#  'Chris MD has been robbed this whole time Hugh Wizzy was 20 meters off his line',
#  'Viks foot bends and he instantly turned into Suarez ',
#  '19:07 “we’re not your parents, keep going” ',
#  'Manny is so nice and humble man. Love him',
#  '35:35 there was about 4 balls juggling in a row there',
#  'Sidemen are literally the best can’t wait for the charity match next week',
#  'I know for a fact that Vik HATES any football related video and he does it by sheer pressure',
#  'Simon is actually too good',
#  'The sudden mom joke caught me off guard lol',
#  'This is to fkn good ',
#  'The Race at the end was as follows 1st-Manny 2nd-Harry 3rd-Theo',
#  'I feel so bad for Vik, I know exactly how it feels to be in his position, I experience that every PE lesson, lol.',
#  "Great vid! But sometimes the camera's that where focused on the guys not shooting could use more contrast and saturation. It wasnt really consistent throughout the video, and sometimes it looked a bit bland.",
#  '13:20 that gave me chills',
#  'I love the Chris style editing!',
#  'JJ shouting bunda caught me so off guard',
#  '16:14 That laugh ',
#  'Sick video. Can’t wait for the charity match. It’s gonna be amazing!',
#  'Love the commentary added in',
#  "Vik's face after he hurt his ankle is hilarious im sorry",
#  'Chris just getting roasted the whole video ',
#  'The edits on this video had me howling ',
#  'Why do I have a feeling Callux is sandbagging and is going to show up big in the Charity Match. Similar to his "If I Run Faster Than KSI, I Win $20,000" video.',
#  'Sidemen never disappoint, always upping the bar lads',
#  'Great vid Declan too much rice was hilarious ',
#  'Love how Keane is just roasting pie throughout',
#  'Man, I miss football videos from them.',
#  'Manny\n \nPace: 85                    Shooting: 82\nDefense: 78              Dribble: 83',
#  'This personally looked like a more sidemen video but I still loved it',
#  "I know I'm not the only one hyped up for the charity match, this years picks are amazing!!",
#  'Pie looks so happy to be there',
#  'Considering chrisMD is a football YouTuber, he had an absolute howler',
#  'Josh and tobi are walking normally it feels so weird when they got the stick',
#  'Theo baker is honestly so good',
#  'Vik is actually the funniest guy in all of this, without even trying to be',
#  'Well they can never make a bad vid. It’s always a banger. Love the sidemen man',
#  'Finally a football video !!!',
#  'this video made me nostalgic....we all grew up on the sidemen football videos',
#  "never thought I'd see the day Vik missed a pen",
#  'Harry had missed a penalty this year. In Chris’s video with Cal the Dragon',
#  'Vik is the most uncoordinated human being I’ve ever seen. He has 0 coordination with his body.',
#  'nostalgia always hits when sidemen upload football videos to their main channel again. nothing can top these vids!',
#  "i've missed sidemen football videos so much",
#  'Bro sometimes I forget that Simon is so Ridiculously good at Football',
#  'the throwback with callux’s famous quote ',
#  '48.10 Theo laughs exactly like KSI ',
#  '4:32 - Great ball control Behz',
#  'Tbh I’ll gladly watch a hour long video of sidemen training vik…..',
#  '17:15 “did your hair get in your eyes” the fact that no one acknowledged this peak humour is wack',
#  'Can Vik please learn how to kick a damn ball? No one is asking him to dribble, it’s been close to a decade xD',
#  'Love to see Ivan Toney coming out as support',
#  'honest question, why didn’t they get Ben Foster in for the Sidemen Charity?',
#  'Tobi and Vik just make me smile a they are so similar\n\nThe top duo !!!',
#  'When the game is on line Vick stomps easily ',
#  "why don't they teach vik how to play football",
#  'I feel like vik is just in these videos to make the rest of them feel better about themselves',
#  'Looks like vikk needs to actually use 0.0000001% of his power',
#  '4:33 the camera man is so evil for pitting the camera on Ethan',
#  'Last challenge just made me want to go watch the one Simon and JJ did on Simon’s channel years ago',
#  "More than Football there is Behzinga's scratchy balls ",
#  'The opposing fans are great, more fans in vids would be cool as long as they don’t take away from it',
#  'Yo editor leave pie alone man hes a decent goalie',
#  'Nothing better than having pie while watching sidemen',
#  "The crowd is the prime representative of the bri'ish people",
#  'Some of the stuff Simon does with a football is outstanding',
#  'Vik needs to get the match ball in the charity match',
#  'Simons age catching up with him. was expecting so much more from him',
#  'The Roy Keane clips killing me ',
#  'Omg callux and Harry are just Funny',
#  'Awe when Toby said "That\'s my brother" That was so cute',
#  'Bog shushing and swearing at the fans is the most Harry thing ever ',
#  'Manny is so cracked bro…that first touch ',
#  'icl manny always has so much style and coolness with a football',
#  'That touch from manny was insane',
#  'Simons ball speed is insane',
#  "Honestly the first Sidemen sunday i've been excited for in a while",
#  "Can't wait to be there next Saturday",
#  'Respect to vikk for committing',
#  'I have brought tickets so I’m gonna be going to the charity match',
#  'After so many years of the sidemen doing football challenges like these how has vik not learned to at least kick properly. Worst footballer in the sidemen',
#  'That man in the red and white stripes is one of the best if not the best at warzone. ',
#  '"IT\'S ON THE WRONG SIDE"',
#  'Pie miles off the line for Vik’s pen',
#  'Love it when u do football',
#  'The editing was elite',
#  "5:41 and pause.\nHarry's limbs are going on all 6 tridimensional planes of existence",
#  'JJ once again is absent ',
#  '‘it’s on the wrong side’ has the same energy as ’don’t waste the mixture’',
#  'Manny was sick. So underrated',
#  '13:28 wholesome moment',
#  'Harry was right, It was on the wrong side',
#  "Callux was the MVP of the video, most balls scored near the goal, and oof guess who's gonna miss the charity match,  this guy ",
#  '24:30 edit made me laugh so hard',
#  "As someone who doesn't know anything about football, this was incredible.",
#  'Preface looks unreal what a legend',
#  'Viks power and connections are soo much better than they used to be, it’s kinda crazy how much he’s improved lol',
#  'we need more football vids',
#  'This huge debate has finally been settled',
#  'Not got much hope for pie in goal ',
#  'When Toby said “ that’s my brother “ I shed a tear \U0001f979',
#  'Harry and behz had more control over his pint than the ball 38:40',
#  'I love how vik tries so much in these videos',
#  'This is a roast video not a football video hahaha so good !!',
#  'Simon is a beast!',
#  'Love Cal but he looks so unathletic when tried to play  but definitely makes the video entertaining',
#  'This looks so much fun. I wish I could do this one day',
#  'How many footballs do the sidemen lose after doing a football video lol ',
#  'Why hasn’t fifa put the side men into a rest of the world squads! Like put them hashtag United etc in there',
#  '"It\'s Declan too much Rice" \nSavage Simon.',
#  'Didn’t know that manny is fire at football',
#  'It will be an healthy competition between speed and vik',
#  '17:16 low key one of the best jokes I’ve heard in a long time',
#  'Put Ethan on penalties, I’m not joking ',
#  'Manny must get a huge ego boost with these lot',
#  'Pie’s transformation is incredible. Pisses all over Bez’s',
#  '18:33 "Declan Too Much Rice" good one Simon lmaooo',
#  'The vik slow mo  ',
#  "Can't believe the charity match is next week feels like I've been waiting forever but somehow it's already the end of September",
#  'The editing on this is elite...',
#  'Viks ankle doesn’t jiggle jiggle, it folds',
#  'Harry and Simon Are so good and also sideman are getting old pie face is so good at goalie',
#  'Not seeing many comments about how incredible pie face looks? Looks like a different human being all together, congrats to him.',
#  'God who did the editing i love this video ️',
#  'These football sessions are my favorite of the Sidemen content',
#  'Is it me or do the sidemen play better when they r in pressure',
#  'This is fun! But not gonna lie, I kinda miss seeing KSI in this videos!',
#  '“Did your hair get in your eyes?” ',
#  'Manny is packing bro  \nSimone: he got back bro ',
#  '34:29 that LeBron "silencer" celebration',
#  "I'm so surprised by Harry's score in the passing one. Where did the Kicktown owner go?",
#  'I barely recognised pieface, he looks amazing ',
#  'Finally more football',
#  'Simon and Theo had exactly the same total, far behind for 3rd was Manny and close to him was Chris. I guesss the total scores are not very accurate hahaha',
#  'Absolutely love this video',
#  'Genuinely enjoyed this vid',
#  'Seeing Harry score a worldie made me so happy',
#  'Pie looks incredible and I love that man',
#  'The spaceman getting hit by Ethan’s ball I’m dead',
#  'Pie face about to carry sidemen to the win',
#  'Who’s the best sideman at football? They will probably need the other half of them to find that out?',
#  '31:51 best moment',
#  "This is genuinely one of the best and funniest videos that sidemen has created.Can't wait for the charity match.Odds on 10 that VIKSTAR and DEJI will score.Also,why is Theo Baker 83 rated but CHRISMD and Miniminter 82 rated? EA needs to do some explanation",
#  "The disrespect of Simon standing up before Lux's ball reached the goal",
#  'Is it just me or did it seem like Theo low-key is jealous of ChrisMD in this video',
#  '3:44 cmon simon show them whos boss LMAO',
#  'editor was feeling himself today',
#  "Is Chrismd playing for sdmnfc this time? or is he playing for all-stars cause if his all-stars game over Chrismd and Noah Beck team up that's game over",
#  'Love the short interviews after each round, gives me office vibes! Cannot wait for the charity match next week!',
#  'Now this is a sidemen Sunday football video ',
#  'Shooting freekicks with a pint in hand is the most English thing ever.',
#  'The “ its declen to much rice” comment senttt mee ',
#  'Pies transformation is insane ',
#  'Manny developed the dad genes he became to op',
#  'When they told Manny to do his free kick stance ',
#  'Pieface looks amazing! Love the transformation',
#  "I don't know why but I really love seeing pie in his argyle kit",
#  'Why did w2s get more pens stat than Chrismd when Chris scored all of them and Harry didn’t',
#  'Editor just bullying the gk is so funny',
#  'Man said due to personal reasons…..isn’t he in tour ',
#  'How did Harry and Ethan end up with pints again. First on train like KSI for 24 hours now this video. Swear these two always turn to drink. But I love it hope to see them both having a pint on the pitch during the game next week',
#  'Sidemen Sunday aint the same when JJ is absent',
#  "Josh's using a crutch but his injury is a bruised rib ",
#  'The edits in this video are elite',
#  'pie was falling about 5 seconds before Harrys second pen, he had no idea where he wanted to shoot but shot into pies face',
#  '11:39 \nMe talking to myself in the mirror after my mom calls me a failure',
#  'What an edit today  sidemens editors dont disappoint ',
#  'I’m not sure whats more impressive. \nPie faces’ transformation, or how Vik is standing after that volley ',
#  'Theo Baker is actually really good.',
#  'This entire vid was quality',
#  'Incredible goalkeeping',
#  'Callus looks like a Sunday league coach',
#  'I really just want Vik to get a coach to train him. He has so much potential!',
#  '22:47 that was ice cold Harry I rate that so much',
#  'I swear there are parts where I hear ksi laughing ️',
#  '"Did your hair get in your eyes?" \n\nUnderrated comment ',
#  'Before everyone nocks down pie\n\nIts harder being a goal keeper than it looks',
#  'Yes! More sports!',
#  '25:43 This clip was perfect I died ️',
#  'we are just gonna ignore the fact that Tobii said Manny looks thick?',
#  'they should make a video of vik getting better at football',
#  '0:35, 4:32, 5:19, 6:05, 6:34, 8:00, 8:35, 13:07 Ethan is getting caught in 4K ',
#  'Loved this ',
#  'Chris should have been the highest FK , man has got robbed.',
#  'That is a mad transformation by Pieface. Hopefully we can see Randolph do the same soon',
#  '"declan ate too much rice" ',
#  'Atrocious to not see iShowSpeed here. A true baller.',
#  'Ethan looks like a rugby player playing football',
#  'Pies Transformation is insane   big up pieface',
#  "Does anyone else play a drinking game watching these vids? Everytime Behz grabs his crotch, take a shot. I'm wasted....",
#  'Dang sidemen can never make a bad video anymore, all their videos never disappoint. Its so entertaining to watch. I cant wait to watch the sidemen play in the charity match once again.',
#  'Honestly, Chris 2 free kicks in his own words, “any Sunday leave goalie would have scored that.” I used to like him, but he’s just a bit too cocky now',
#  'Great video just find it a little stupid that you’d do a challenge amongst the sidemen when 2 of them aren’t there surely that’s something you’d film with all 7',
#  '13:25 that manny cntrol was sick',
#  'Vik representing the blayards ️️',
#  'Should do this with Ben foster in goal',
#  'The edits are 10/10 lmao. Banger video as always, I cant wait for the match',
#  'banger vid!! great job chip!',
#  'Only if there was a part two uk again. With Randolph, ksi , Tobjizle,zerkaa, calfreezy Ellum, willne, chunks,niko,aj, sharky, deji, imalex, viz, chippo, tgfbros and king kenny',
#  "But How's the pace 5 different between Harry and theo but only 3 between manny and theo, the margin was tighter between Harry and theo ",
#  'tobi has crutches for a torn hamstring?',
#  'Is it bad that I was expecting a birthday video from the Sidemen?',
#  "Can't wait for the charity match!",
#  'the Chris x Theo competition/rivalry is the best',
#  "Pie isn't uhhhh a very good keeper is he ",
#  'The O.G SIDEMEN FOOTBALL VIDEOS!',
#  'how can vik play football all this years but not get better',
#  "i just can't believe they got a crowd now now they are getting somewhere in life where they don't need to look at the comments now they have fans watching them every time they play football.",
#  '39:59 , that transition was clean, and a great goal to follow it as well',
#  'Coming home and watching there videos before school the next morning ️ I always look forward to there videos ',
#  '37:13 speaking facts',
#  'Damn pieface looking so slim man, what a goat',
#  'The colour grading is different in every shot and it’s driving me crazy hahaha',
#  '“Here we go 1940s is back.” ',
#  'Tobi and Vik just make me smile a they are so similar\n\nThe top duo !!!',
#  'Thanks! Sidemen for this banger video ',
#  'Pie has lost a lot of weight! Good on him',
#  'The astronaut got me',
#  "awh tobi's 'thats my brother' love them.",
#  'behz and simon chcking out mannys back had my crying',
#  'Love to see Manny with the boys again! Big up',
#  'Nice to see josh with the same kit and work rate as messi lmao.',
#  'but seriously, who let Manny have all that cake?',
#  '33:15 man uses his 2% skills…',
#  'That edit on Manny is too clean',
#  'tobi and josh holds the stick \n0:47\nthen walk normaly !!?!? ',
#  'Harry is an absolute volley merchant. Madness',
#  'Please post more sidemen football️',
#  'Manny is a baller!',
#  'This feels like a chrismd football vid with all the edits',
#  "I don't get how can someone be as bad as vik in football....a guy who has never touched a football can play better than him",
#  'I knew pie was tall but dude is massive! And I don’t mean big. Bro is taller than Minter',
#  'These editors do such a great job ',
#  'thankyou to the goolie pie for trying his best i bet the cameras put some pressure on him',
#  'Vik has used the same boots for the last 4 years ',
#  'Possibly one of the most boring sidemen Sundays ever',
#  'Chris md was getting humbles lol. Callux was hilarious.',
#  "I can't explain it but Theo looks like the number 7",
#  'The audience’s insults were way to funny',
#  '39:59 best transition ever',
#  'Vikk has done so many football videos and it looks like he has barely learned anything.  Its actually baffling how someone can be that uncoordinated.  Does he have some sort of physical disability?',
#  'Subtitles would be nice for the crowd',
#  'Reminder: No Sidemen Sunday next week (the 25th) bc the charity match would be the "sidemen sunday"',
#  "3:53  am I the only one that's seeing the plane up there",
#  'Simon is the best YouTube footballer.There is no argue about that.',
#  'The use of the Roy Keane clips is elite',
#  'I like the celebration that Chris did recreating Paul Aguilar’s Celebration vs Toluca I really like that',
#  "am i the only one who thinks Josh always sounds like he's got peanut butter stuck in his mouth lol. Tough to understand sometimes",
#  'I think we all have to agree now..SIMON IS THE BEST YOUTUBE FOOTBALLER ',
#  'Camera man understood the assignment at 4:30',
#  'Harry had me in tears during this one ',
#  'Amazing video we need more futball videos',
#  'Vik missed those pens cos he’s wearing that shirt',
#  'I didn’t kno Theo was cold like this',
#  "I've just started watching but looks like a great idea. #UpChrisMD",
#  'Bro the charity match will be during mySAT exam ',
#  'Definitely watching the Sidemen Saturday - Charity Football Match next week, Great vid yet again btw.',
#  "48:09 Vikk doesn't allow his friends being left hanging",
#  'Sidemen videos are so much better without KSI screaming every 3 seconds.',
#  'The Roy Keane clips ',
#  'I remember watching chris when he was humble...',
#  'Harry got home from Australia fairly fast',
#  "Always makes mine and everybody's days better whenever the sidemen upload",
#  "Xavy Rusan - curve ball fits perfectly with manny's touch",
#  'Chris, Manny & Theo are all better than Simon, he just has the most power.',
#  'Can someone explain why simon is in a NY redbull kit? Coming from a nyredbull fan.',
#  'Cant wait for the match gonna be sick',
#  'The football cutaways were legendary shout out to the most elite editors in the UK. \nSome how Sidemen have them all on their team.',
#  'Get the F2 in the charity match!',
#  "The video I've actually been waiting for",
#  'Simon freekick edit goes crazzyyy',
#  'Great MoreSidemen video guys!!']

# %%
len(comments)
# Out:
# 2622

# %%
# to scrape time when comment was posted
tm_tags = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
for tm in tm_tags:
    if tm.text is None:
        Time.append("--")
    else:
        Time.append(tm.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(5)
comment_time[:500]

# to scrape comment likes
like_tags = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for like in like_tags:
    if like.text is None:
        Likes.append("--")
    else:
        Likes.append(like.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
Likes[:500]
# Out:
# ['',
#  '17K',
#  '',
#  '1.9K',
#  '',
#  '2.4K',
#  '',
#  '607',
#  '',
#  '1.7K',
#  '',
#  '1.5K',
#  '',
#  '7.6K',
#  '',
#  '103',
#  '',
#  '73',
#  '',
#  '95',
#  '',
#  '208',
#  '',
#  '224',
#  '',
#  '385',
#  '',
#  '31',
#  '',
#  '61',
#  '',
#  '231',
#  '',
#  '53',
#  '',
#  '4.8K',
#  '',
#  '59',
#  '',
#  '46',
#  '',
#  '6',
#  '',
#  '115',
#  '',
#  '10',
#  '',
#  '2.3K',
#  '',
#  '12',
#  '',
#  '5',
#  '',
#  '3',
#  '',
#  '16',
#  '',
#  '3',
#  '',
#  '4.6K',
#  '',
#  '8',
#  '',
#  '19',
#  '',
#  '3',
#  '',
#  '50',
#  '',
#  '3',
#  '',
#  '3.2K',
#  '',
#  '3',
#  '',
#  '7',
#  '',
#  '4',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '1K',
#  '',
#  '2',
#  '',
#  '3',
#  '',
#  '4',
#  '',
#  '2',
#  '',
#  '5',
#  '',
#  '927',
#  '',
#  '19',
#  '',
#  '5',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '3',
#  '',
#  '641',
#  '',
#  '4',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '502',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1.1K',
#  '',
#  '1',
#  '',
#  '3',
#  '',
#  '1',
#  '',
#  '5',
#  '',
#  '1',
#  '',
#  '758',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '388',
#  '',
#  '2',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '2.1K',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '1.1K',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '502',
#  '',
#  '2',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '5',
#  '',
#  '2',
#  '',
#  '71',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '264',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '363',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '4',
#  '',
#  '',
#  '',
#  '753',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '189',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '74',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '157',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '64',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '39',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '36',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '2',
#  '',
#  '89',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '112',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '83',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '78',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '12',
#  '',
#  '1',
#  '',
#  '1.2K',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '78',
#  '',
#  '517',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '574',
#  '',
#  '1',
#  '',
#  '8',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '56',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '16',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '105',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '153',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '229',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '194',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Youtube=pd.DataFrame({})
Youtube['Comments'] = comments[:500]
Youtube['Comment_time'] = comment_time[:500]
Youtube['Comment upvotes'] = No_of_Likes[:500]

#Printing dataframe
Youtube
# Out:
#                                               Comments  Comment_time  \
# 0             Pie looks incredible and I love that man  20 hours ago
# 1    Vik is so humble he didn’t show his true power...  15 hours ago
# 2    Vik is so down to Earth. He thought he’d go ez...  17 hours ago
# 3    Manny seems to be so much more confident and l...  20 hours ago
# 4    Nothing hits more than a cold Sunday watching ...  14 hours ago
# ..                                                 ...           ...
# 495  The football cutaways were legendary shout out...  20 hours ago
# 496                   Get the F2 in the charity match!   9 hours ago
# 497           The video I've actually been waiting for   7 hours ago
# 498                  Simon freekick edit goes crazzyyy   4 hours ago
# 499                     Great MoreSidemen video guys!!   2 hours ago
#
#     Comment upvotes
# 0               17K
# 1              1.9K
# 2              2.4K
# 3               607
# 4              1.7K
# ..              ...
# 495               4
# 496
# 497
# 498
# 499               1
#
# [500 rows x 3 columns]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="b13dd620933d183280688a021e047639")>>

# %% [markdown]
# # Q10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location.
# You have to scrape hostel name, distance from city centre, ratings, total reviews,
# overall reviews, privates from price, dorms from price, facilities and property description.

# %%
driver = webdriver.Chrome(r'chromedriver.exe')
driver.get("https://www.hostelworld.com/")
driver.maximize_window()
time.sleep(2)

# %%
#select london
driver.find_element(By.ID,'location-text-input-field').click()
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="search-input-field"]').send_keys('London')
time.sleep(4)


# do click on search button
driver.find_element(By.XPATH,'//*[@id="predicted-search-results"]/li[2]').click()
driver.find_element(By.ID,'search-button').click()

# %%
# Make empty lists
Hostel_Name = []
Distance = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(2)
        
    # Distance from city
    distance = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for d in distance:
        Distance.append(d.text)
    time.sleep(2)
        
    #Review    
    review = driver.find_elements(By.XPATH,'//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(2)
    
    # Total number of reviews     
    t_review = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
    for t in t_review:
        total_reviews.append(t.text)
    time.sleep(2)
    
    # facilities
    service = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(2)
    
    # Prices    
    prices = driver.find_elements(By.XPATH,'//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(2)    
    try:
        next_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
        time.sleep(2) 

# Separate  Privates_From price  and  Dorms_From price
private = []
for i in range(0,len(price),2):
    private.append(price[i])
time.sleep(2)

dorms = []
for i in range(1,len(price),2):
    dorms.append(price[i])

# %%
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]/a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(2)    
        
    try:
        next_button = driver.find_element(By.XPATH,'//div[@class="pagination-item pagination-prev"]')
        next_button.click()
    except:
        break
        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(2)
    
    # Property Description
    try:
        pd = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(2)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(2)

for i in all_text:
    Rating.append(i[0])

# %%
print(
    len(Hostel_Name),len(Distance),len(Rating),len(total_reviews),len(overall_review),
    len(private),len(dorms),len(facilities),len(property_description))
# Out:
# 30 30 30 30 32 30 30 30 30

# %%
Hostel=pd.DataFrame({"Hostel Name":Hostel_Name,"Distance":Distance,"Rating":Rating,"Total Reviews":total_reviews,"Overall Review":overall_review[:30],
                     "Private Price":private,"Dorms Price":dorms,"Facilities":facilities,"Property Description":property_description})
Hostel
# Out:
#                                 Hostel Name                          Distance  \
# 0               Wombat's City Hostel London   Hostel - 3.6km from city centre
# 1                  St Christopher's Village   Hostel - 1.8km from city centre
# 2                      Urbany Hostel London   Hostel - 5.4km from city centre
# 3                          Generator London     Hostel - 3km from city centre
# 4         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 5   Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 6                             Pickwick Hall   Hostel - 2.3km from city centre
# 7                            Phoenix Hostel   Hostel - 4.2km from city centre
# 29     No    875 Total Reviews       Fabulous   Privates From\nRs9268
#
#                      Dorms Price  \
# 0   Dorms From\nRs3688.91 Rs2951
# 1   Dorms From\nRs2057.69 Rs1852
# 2             Dorms From\nRs3984
# 3             Dorms From\nRs3146
# 4             Dorms From\nRs1596
# 5             Dorms From\nRs1756
# 6             No Dorms Available
# 7   Dorms From\nRs2039.96 Rs1836
# 8             No Dorms Available
# 9             Dorms From\nRs1623
# 10  Dorms From\nRs2057.69 Rs1852
# 11            Dorms From\nRs2750
# 12  Dorms From\nRs1893.44 Rs1704
# 13  Dorms From\nRs4045.91 Rs3237
# 14            Dorms From\nRs4435
# 15            Dorms From\nRs3903
# 16            Dorms From\nRs3843
# 17            No Dorms Available
# 18  Dorms From\nRs1663.82 Rs1497
# 19  Dorms From\nRs2746.54 Rs2472
# 20   Dorms From\nRs1860.6 Rs1675
# 21  Dorms From\nRs8514.59 Rs7237
# 22            Dorms From\nRs3113
# 23            Dorms From\nRs2572
# 24            Dorms From\nRs1596
# 25            No Dorms Available
# 26            Dorms From\nRs2954
# 27            Dorms From\nRs2331
# 28            Dorms From\nRs2602
# 29            Dorms From\nRs4520
#
#                                            Facilities Property Description
# 0     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 1     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 2     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 3     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 4     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 5                                           Free WiFi       No Description
# 6                                      Free Breakfast       No Description
# 7     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 8     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 9     Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 10    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 11                          Free WiFi\nFree Breakfast       No Description
# 12    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 13                          Free WiFi\nFree Breakfast       No Description
# 14                          Free WiFi\nFree Breakfast       No Description
# 15  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...       No Description
# 16    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 17    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 18    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 19    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 20    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 21                                          Free WiFi       No Description
# 22               Follows Covid-19 sanitation guidance       No Description
# 23    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 24               Follows Covid-19 sanitation guidance       No Description
# 25                                          Free WiFi       No Description
# 26    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 27                          Free WiFi\nFree Breakfast       No Description
# 28    Free WiFi\nFollows Covid-19 sanitation guidance       No Description
# 29    Free WiFi\nFollows Covid-19 sanitation guidance       No Description

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="86cae6faa47a5f4382fd56556166cd9f")>>
