# %%
# importing necessary

import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import requests
import re
from selenium.webdriver.support.ui import WebDriverWait
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Q1

# %%
driver=webdriver.Chrome('chromedriver.exe')

# Getting the webpage of url 

url=('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
driver.get(url)

# %%
Rank = []
Name = []
Artist = []
UploadDate = []
Views = []


# Scraping Rank of the videos
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
#scrapping rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        Name.append(i.text)
except NoSuchElementException:
    Name.append("_")
    
    
#scrapping Artist
try:
    for i in driver.find_elements(By.XPATH,'//*[@id="mw-content-text"]/div[1]/table[2]/tbody/tr/td[3]'):
        Artist.append(i.text)
except NoSuchElementException:
    Artist.append("_")
    
    
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,' //table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]'):
        UploadDate.append(i.text)
except NoSuchElementException:
    UploadDate.append('-')
# Scraping Views of videos

try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        Views.append(i.text)
except NoSuchElementException:
    Views.append("_")

# %%
# Creating DataFrame from scraped data
wikipedia = pd.DataFrame({})
wikipedia['Rank']=Rank
wikipedia['Name']=Name
wikipedia['Artist']=Artist
wikipedia['Upload Date']=UploadDate
wikipedia['Views']=Views

# %%
wikipedia
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                                     "Axel F"[36]
# 18  18.                          "Thinking Out Loud"[37]
# 19  20.                        "Baa Baa Black Sheep"[38]
# 20  21.                                 "Dark Horse"[39]
# 21  22.                                      "Faded"[40]
# 22  23.                             "Girls Like You"[41]
# 23  24.                                 "Let Her Go"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                                    "Perfect"[45]
# 27  28.           "Waka Waka (This Time for Africa)"[46]
# 28  29.                               "Shake It Off"[47]
# 29  30.          "Humpty the train on a fruits ride"[48]
#
#                                            Artist        Upload Date  Views
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  11.40
# 1                                      Luis Fonsi   January 12, 2017   7.98
# 2                                     LooLoo Kids    October 8, 2016   6.47
# 3                                      Ed Sheeran   January 30, 2017   5.81
# 4                                     Wiz Khalifa      April 6, 2015   5.64
# 5                      Cocomelon – Nursery Rhymes        May 2, 2018   5.63
# 6                                       ChuChu TV      March 6, 2014   4.90
# 7                                     Mark Ronson  November 19, 2014   4.70
# 8                                     Miroshka TV  February 27, 2018   4.65
# 9                                             Psy      July 15, 2012   4.55
# 10                                     Get Movies   January 31, 2012   4.51
# 11                     Cocomelon – Nursery Rhymes       May 24, 2018   4.40
# 12                                      El Chombo      April 5, 2018   4.07
# 13                                       Maroon 5   January 14, 2015   3.76
# 14                                     Katy Perry  September 5, 2013   3.66
# 15                                    OneRepublic       May 31, 2013   3.65
# 16                                  Justin Bieber   October 22, 2015   3.59
# 17                                     Crazy Frog      June 16, 2009   3.52
# 18                                     Ed Sheeran    October 7, 2014   3.50
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018   3.38
# 20                                     Katy Perry  February 20, 2014   3.35
# 21                                    Alan Walker   December 3, 2015   3.34
# 22                                       Maroon 5       May 31, 2018   3.33
# 23                                      Passenger      July 25, 2012   3.30
# 24                               Enrique Iglesias     April 11, 2014   3.27
# 25                                    Major Lazer     March 22, 2015   3.26
# 26                                     Ed Sheeran   November 9, 2017   3.26
# 27                                        Shakira       June 4, 2010   3.25
# 28                                   Taylor Swift    August 18, 2014   3.21
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018   3.17

# %%
driver.close()

# %% [markdown]
# # Q2

# %%
driver=webdriver.Chrome('chromedriver.exe')

# Getting the webpage of mentioned url 
url=('https://www.bcci.tv/')
driver.get(url)

# %%
#clickin on International tab
International = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a') # click button
International.click()

# %%
#Creating Empty List
Name=[]
Series=[]
Place=[]
Date=[]
Time=[]
#Scrapping Name
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]'):
        Name.append(i.text.replace('-',""))
except NoSuchElementException:
    Name.append('-')

#Scrapping Series
try:
    
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding"]'):
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')
#scrapping Place
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]'):
        Place.append(i.text)
except NoSuchElementException:
    Place.append('-')
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]'):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')
#Scrapping Time
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
        Time.append(i.text.replace('IST',""))
except NoSuchElementException:
    Time.append('-')

# %%
Fixtures=pd.DataFrame({})
Fixtures['Title']=Series
Fixtures['Name']=Name
Fixtures['Place']=Place
Fixtures['Date']=Date
Fixtures['Time']=Time

# %%
Fixtures
# Out:
#                                            Title       Name  \
# 0  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   1st ODI
# 1                           ASIA CUP WOMENS 2022  4th T20I
# 2                           ASIA CUP WOMENS 2022  5th T20I
# 3  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   2nd ODI
# 4                           ASIA CUP WOMENS 2022  6th T20I
# 5  SOUTH AFRICA TOUR OF INDIA ODI SERIES 2022-23   3rd ODI
#
#                                                Place         Date      Time
# 0  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...   6 OCT 2022  1:30 PM
# 1              Sylhet International Cricket Stadium,   7 OCT 2022  1:00 PM
# 2              Sylhet International Cricket Stadium,   8 OCT 2022  1:00 PM
# 3                JSCA International Stadium Complex,   9 OCT 2022  1:30 PM
# 4              Sylhet International Cricket Stadium,  10 OCT 2022  1:00 PM
# 5                              Arun Jaitley Stadium,  11 OCT 2022  1:30 PM

# %%
driver.close()

# %% [markdown]
# # Q3

# %%
driver=webdriver.Chrome('chromedriver.exe')

# get webpage
driver.get("https://www.guru99.com/")
driver.maximize_window()

# %%
# Click Selenium Button
Selenium = driver.find_element(By.XPATH,'//div[@class = "wp-block-kadence-column inner-column-2 kadence-column_f38d98-3a"]') # click button
try:
    Selenium.click()
except ElementNotInteractableException:#handling element not clickable exception
    driver.get(Selenium.get_attribute('href'))
time.sleep(3)

# %%
# Click selenium exception handling  Button
exception_handling = driver.find_element(By.XPATH,"//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    exception_handling.click()
except ElementNotInteractableException:  #if the above code doesn't work/is not clickable then, the below code will handle it
    driver.get(exception_handling.get_attribute('href'))

# %%
name=[]
desc=[]
#Scrapping Name
for i in driver.find_elements(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/p[1]/strong"):
    name.append(i.text)
for i in driver.find_elements(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/p[1]"):
    desc.append(i.text)

# %%
Selenium_Exception=pd.DataFrame()
Selenium_Exception['Exception name']=name
Selenium_Exception['Description']=desc
Selenium_Exception
# Out:
#                    Exception name  \
# 0  1. ElementNotVisibleException:
#
#                                          Description
# 0  1. ElementNotVisibleException: This type of Se...

# %% [markdown]
# # Q4

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

#Opening the website on automated website
driver.get("https://www.statisticstimes.com/")

# %%
#Selecting Economy Section
a=driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")

# %%
x=a.get_attribute("href")
driver.get(x)

# %%
#Selecting GDP of Indian States
y=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")

# %%
driver.get(y.get_attribute("href"))

# %%
#Scraping State

state=[]

a=driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in a:
    state.append(i.text)
s1=state[0:33]

# %%
#Scraping GSDP(19-20)
b1=[]

b=driver.find_elements(By.XPATH,"//td[@class='data']")
for i in b:
    b1.append(i.text)
gs1920=[]
gs1920=b1[::5]

# %%
#Scraping Share-18-19
share=b1[1::5]

# %%
#Scraping GDP Billion
gb=b1[2::5]

# %%
#Scraping GSDP-18-19
c=driver.find_elements(By.XPATH,"//td[@class='data sorting_1']")
gs1819=[]
for i in c:
    gs1819.append(i.text)

# %%
#Scraping Rank
d=driver.find_elements(By.XPATH,"//td[@class='data1']")
rank=[]
for i in d:
    rank.append(i.text)

# %%
#Creating Dataframe
data=pd.DataFrame({"Rank":rank[0:33],"State":s1,"GSDP-19-20":gs1920[0:33],"GSDP-18-19":gs1819[0:33],"Share-18-19":share[0:33],"GDP-Billion":gb[0:33]})
data
# Out:
#    Rank                      State GSDP-19-20 GSDP-18-19 Share-18-19  \
# 0     1                Maharashtra          -  2,632,792      13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208       8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764       8.39%
# 3     4                    Gujarat          -  1,502,899       7.96%
# 4     5                  Karnataka  1,631,977  1,493,127       7.91%
# 5     6                West Bengal  1,253,832  1,089,898       5.77%
# 6     7                  Rajasthan  1,020,989    942,586       4.99%
# 7     8             Andhra Pradesh    972,782    862,957       4.57%
# 8     9                  Telangana    969,604    861,031       4.56%
# 9    10             Madhya Pradesh    906,672    809,592       4.29%
# 10   11                     Kerala          -    781,653       4.14%
# 11   12                      Delhi    856,112    774,870       4.10%
# 12   13                    Haryana    831,610    734,163       3.89%
# 13   14                      Bihar    611,804    530,363       2.81%
# 14   15                     Punjab    574,760    526,376       2.79%
# 15   16                     Odisha    521,275    487,805       2.58%
# 16   17                      Assam          -    315,881       1.67%
# 17   18               Chhattisgarh    329,180    304,063       1.61%
# 18   19                  Jharkhand    328,598    297,204       1.57%
# 19   20                Uttarakhand          -    245,895       1.30%
# 20   21            Jammu & Kashmir          -    155,956       0.83%
# 21   22           Himachal Pradesh    165,472    153,845       0.81%
# 22   23                        Goa     80,449     73,170       0.39%
# 23   24                    Tripura     55,984     49,845       0.26%
# 24   25                 Chandigarh          -     42,114       0.22%
# 25   26                 Puducherry     38,253     34,433       0.18%
# 26   27                  Meghalaya     36,572     33,481       0.18%
# 27   28                     Sikkim     32,496     28,723       0.15%
# 28   29                    Manipur     31,790     27,870       0.15%
# 29   30                   Nagaland          -     27,283       0.14%
# 30   31          Arunachal Pradesh          -     24,603       0.13%
# 31   32                    Mizoram     26,503     22,287       0.12%
# 32   33  Andaman & Nicobar Islands          -          -           -
#
#    GDP-Billion
# 0      399.921
# 1      247.629
# 2      240.726
# 3      228.290
# 4      226.806
# 5      165.556
# 6      143.179
# 7      131.083
# 8      130.791
# 9      122.977
# 10     118.733
# 11     117.703
# 12     111.519
# 13      80.562
# 14      79.957
# 15      74.098
# 16      47.982
# 17      46.187
# 18      45.145
# 19      37.351
# 20      23.690
# 21      23.369
# 22      11.115
# 23       7.571
# 24       6.397
# 25       5.230
# 26       5.086
# 27       4.363
# 28       4.233
# 29       4.144
# 30       3.737
# 31       3.385
# 32           -

# %%
driver.close()

# %% [markdown]
# # Q5

# %%
driver=webdriver.Chrome('chromedriver.exe')
url=('https://github.com/')
driver.get(url)

# %%
a=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
driver.get(a.get_attribute("href"))

# %%
#Scraping Repository Title
a=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']")
title=[]
for i in a:
    title.append(i.text)

# %%
#Scraping Repository Description
b=driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
des=[]
for i in b:
    des.append(i.text)

# %%
#Scraping Contributors Count
c=driver.find_elements(By.XPATH,"//a[@class='Link--muted d-inline-block mr-3']")
c1=[]
for i in c:
    c1.append(i.text)

# %%
count=c1[::2]

# %%
data=pd.DataFrame({"Title":title,"Description":des,"Contributors Count":count})
data
# Out:
#                                        Title  \
# 0                freeCodeCamp / freeCodeCamp
# 1                TheAlgorithms / C-Plus-Plus
# 2   firstcontributions / first-contributions
# 3                     TheAlgorithms / Python
# 4                     CodeEditApp / CodeEdit
# 5                           TryGhost / Ghost
# 6                            SigNoz / signoz
# 7                            soxoj / maigret
# 8             FernandaCader / recursos-datos
# 9                          ToolJet / ToolJet
# 10                         leeoniya / uFuzzy
# 11                            iced-rs / iced
# 12                             github / docs
# 13            bufbuild / protoc-gen-validate
# 14       stephrobert / awesome-french-devops
# 15                       palera1n / palera1n
# 16                             novuhq / novu
# 17                               odoo / odoo
# 18        lkwq007 / stablediffusion-infinity
# 19                              nvm-sh / nvm
# 20                    stefanprodan / podinfo
# 21                huggingface / transformers
# 22         kamranahmedse / developer-roadmap
# 23   awesome-selfhosted / awesome-selfhosted
# 24                remoteintech / remote-jobs
#
#                                           Description Contributors Count
# 0   freeCodeCamp.org's open-source codebase and cu...            354,825
# 1   Collection of various algorithms in mathematic...             21,489
# 2   🚀✨ Help beginners to contribute to open source...             28,150
# 3                All Algorithms implemented in Python            146,146
# 4   CodeEdit App for macOS – Elevate your code edi...             15,163
# 5   Turn your audience into a business. Publishing...             41,346
# 6   SigNoz is an open-source APM. It helps develop...              9,385
# 7   🕵️‍♂️ Collect a dossier on a person by usernam...              3,770
# 8   Recopilación de recursos de ciencias de datos ...                102
# 9   Extensible low-code framework for building bus...             13,773
# 10   A tiny, efficient fuzzy search that doesn't suck              1,221
# 11  A cross-platform GUI library for Rust, inspire...             15,654
# 12           The open-source repo for docs.github.com             11,523
# 13  protoc plugin to generate polyglot message val...              2,638
# 14  Une liste de liens permettant de se former aux...                312
# 15  iOS 15.0-15.3.1 tethered checkm8 "jailbreak" (...                271
# 16  ⭐ A fully functional real-time notification ce...             10,332
# 17      Odoo. Open Source Apps To Grow Your Business.             26,451
# 18  Outpainting with Stable Diffusion on an infini...              1,656
# 19  Node Version Manager - POSIX-compliant bash sc...             61,307
# 20            Go microservice template for Kubernetes              3,109
# 21  🤗 Transformers: State-of-the-art Machine Learn...             71,471
# 22  Interactive roadmaps, guides and other educati...            213,805
# 23  A list of Free Software network services and w...            104,950
# 24  A list of semi to fully remote-friendly compan...             20,163

# %%
driver.close()

# %% [markdown]
# # Q6

# %%
driver=webdriver.Chrome(r"chromedriver.exe")

#Opening the website on automated website
driver.get("https://www.billboard.com/")

# %%
#Selecting Charts section 
a=driver.find_element(By.XPATH,"/html/body/div[3]/div[7]/div/div/div/ul/li[1]/h3/a")
driver.get(a.get_attribute("href"))
#Extracting Billboard hot 100
b=driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div[1]/div[2]/span/a")
driver.get(b.get_attribute("href"))

# %%
#Scraping Song Name
name=[]
c=driver.find_element(By.XPATH,"/html/body/div[4]/main/div[2]/div[3]/div/div/div/div[2]/div[2]/ul/li[4]/ul/li[1]/h3")
c=c.text.split("\n")

# %%
#Scraping Song and Artist
d1=[]
d=driver.find_elements(By.XPATH,"//li[@class='o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-padding-l-050 lrv-u-padding-l-1@mobile-max']")
for i in d:
    d1.append(i.text)

# %%
e=[]
for i in d1:
    e.append(i.split("\n"))

# %%
s1=[]
a1=[]
for i in range(0,len(e)):
    s1.append(e[i][0])
    a1.append(e[i][1])

# %%
s1.insert(0,c[0])    #Complete list of Song Names
a1.insert(0,c[1])    #Complete list of Artist Names
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8176/315232344.py in <module>
#       1 s1.insert(0,c[0])    #Complete list of Song Names
# ----> 2 a1.insert(0,c[1])    #Complete list of Artist Names
#
# IndexError: list index out of range

# %%
#Scraping Last Week Rank, Peak Rank, Weeks on board
f1=[]
f=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-m lrv-u-padding-tb-050@mobile-max']")
for i in f:
    f1.append(i.text)

# %%
last_week_rank=[]
peak_rank=[]
weeks_board=[]
last_week_rank=f1[::6]
peak_rank=f1[1::6]
weeks_board=f1[2::6]

# %%
g=driver.find_elements(By.XPATH,"//span[@class='c-label  a-font-primary-bold-l a-font-primary-m@mobile-max u-font-weight-normal@mobile-max lrv-u-padding-tb-050@mobile-max u-font-size-32@tablet']")

# %%
last_week_rank.insert(0,g[0].text)
peak_rank.insert(0,g[1].text)
weeks_board.insert(0,g[2].text)

# %%
data=pd.DataFrame({"Song":s1,"Artist":a1,"Last Week Rank":last_week_rank,"Peak Rank":peak_rank,"Weeks Board":weeks_board})
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8176/218156545.py in <module>
# ----> 1 data=pd.DataFrame({"Song":s1,"Artist":a1,"Last Week Rank":last_week_rank,"Peak Rank":peak_rank,"Weeks Board":weeks_board})
#       2 data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
driver.close()

# %% [markdown]
# # Q7

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
#Opening the website on automated website
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
#Entering Data Science option 
a=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input")
a.click()
a.send_keys("Data Science")

# %%
b=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button")
b.click()

# %%
#Scraping Name and Company
c=driver.find_elements(By.XPATH,"//a[@class='ellipsis']")
name=[]
company=[]
c1=[]
for i in c:
    c1.append(i.text)
    
name=c1[::2]
company=c1[1::2]

# %%
#Scraping Designation
d=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
des=[]
for i in d:
    des.append(i.text)

# %%
#Scraping Skills
f=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
skill=[]
for i in f:
    skill.append(i.text)

# %%
g1=driver.find_elements(By.XPATH,"//a[@class='ellipsis']")
url=[]
for i in g1:
    url.append(i.get_attribute("href"))

# %%
url1=url[::2]
url1
# Out:
# ['https://www.naukri.com/recruiters/aakashharit-1986742?xid=166496004979787600&xp=1',
#  'https://www.naukri.com/recruiters/shravankumargaddam-353487?xid=166496004979787600&xp=2',
#  'https://www.naukri.com/recruiters/marsiantech?xid=166496004979787600&xp=3',
#  'https://www.naukri.com/recruiters/anikagrawal-3647208?xid=166496004979787600&xp=4',
#  'https://www.naukri.com/recruiters/LXP-DATASCIENCE?xid=166496004979787600&xp=5',
#  'https://www.naukri.com/recruiters/abhishekyadav-3450244?xid=166496004979787600&xp=6',
#  'https://www.naukri.com/recruiters/menakav-3213816?xid=166496004979787600&xp=7',
#  'https://www.naukri.com/recruiters/techvantage?xid=166496004979787600&xp=8',
#  'https://www.naukri.com/recruiters/asiflucknowi-4331110?xid=166496004979787600&xp=9',
#  'https://www.naukri.com/recruiters/instafinancials-humanresource?xid=166496004979787600&xp=10',
#  'https://www.naukri.com/recruiters/maheshbabuchanna-1803238?xid=166496004979787600&xp=11',
#  'https://www.naukri.com/recruiters/priyankaakiri-5010064?xid=166496004979787600&xp=12',
#  'https://www.naukri.com/recruiters/kalpana-2078894?xid=166496004979787600&xp=13',
#  'https://www.naukri.com/recruiters/mubarak-2905498?xid=166496004979787600&xp=14',
#  'https://www.naukri.com/recruiters/quantmagnum?xid=166496004979787600&xp=15',
#  'https://www.naukri.com/recruiters/vaishnavikudalkar-5205628?xid=166496004979787600&xp=16',
#  'https://www.naukri.com/recruiters/kapildevang-3169734?xid=166496004979787600&xp=17',
#  'https://www.naukri.com/recruiters/sakshichhikara?xid=166496004979787600&xp=18',
#  'https://www.naukri.com/recruiters/ruchidhote?xid=166496004979787600&xp=19',
#  'https://www.naukri.com/recruiters/manishayadav-4463916?xid=166496004979787600&xp=20',
#  'https://www.naukri.com/recruiters/riyarajesh-4375878?xid=166496004979787600&xp=21',
#  'https://www.naukri.com/recruiters/rashmibhattacharjee-3921774?xid=166496004979787600&xp=22',
#  'https://www.naukri.com/recruiters/faizankareem-3685102?xid=166496004979787600&xp=23',
#  'https://www.naukri.com/recruiters/rithikadadwal-3517898?xid=166496004979787600&xp=24',
#  'https://www.naukri.com/recruiters/ankitshah-21129?xid=166496004979787600&xp=25',
#  'https://www.naukri.com/recruiters/shaunrao-3020604?xid=166496004979787600&xp=26',
#  'https://www.naukri.com/recruiters/azaharshaikh-companyrecruiter?xid=166496004979787600&xp=27',
#  'https://www.naukri.com/recruiters/manas-3159036?xid=166496004979787600&xp=28',
#  'https://www.naukri.com/recruiters/kumar-3378892?xid=166496004979787600&xp=29',
#  'https://www.naukri.com/recruiters/sunilvedula-3392046?xid=166496004979787600&xp=30',
#  'https://www.naukri.com/recruiters/rajatkumar-3295096?xid=166496004979787600&xp=31',
#  'https://www.naukri.com/recruiters/dhruvdevdubey?xid=166496004979787600&xp=32',
#  'https://www.naukri.com/recruiters/jayanthn-3081850?xid=166496004979787600&xp=33',
#  'https://www.naukri.com/recruiters/nikithapalaparthi-5172698?xid=166496004979787600&xp=34',
#  'https://www.naukri.com/recruiters/sreedhar-3824102?xid=166496004979787600&xp=35',
#  'https://www.naukri.com/recruiters/priyakhare-4894796?xid=166496004979787600&xp=36',
#  'https://www.naukri.com/recruiters/amitsharma-4238940?xid=166496004979787600&xp=37',
#  'https://www.naukri.com/recruiters/deepali002g?xid=166496004979787600&xp=38',
#  'https://www.naukri.com/recruiters/shashikantchaudhary-4164854?xid=166496004979787600&xp=39',
#  'https://www.naukri.com/recruiters/brad-4068508?xid=166496004979787600&xp=40',
#  'https://www.naukri.com/recruiters/rutujapawar?xid=166496004979787600&xp=41',
#  'https://www.naukri.com/recruiters/madhusudhansridhar-2705338?xid=166496004979787600&xp=42',
#  'https://www.naukri.com/recruiters/ankitsinha-3398798?xid=166496004979787600&xp=43',
#  'https://www.naukri.com/recruiters/gauravchouhan?xid=166496004979787600&xp=44',
#  'https://www.naukri.com/recruiters/impel?xid=166496004979787600&xp=45',
#  'https://www.naukri.com/recruiters/ashwini-3434922?xid=166496004979787600&xp=46',
#  'https://www.naukri.com/recruiters/balajikolli-2870676?xid=166496004979787600&xp=47',
#  'https://www.naukri.com/recruiters/rajaninagaraj-3387578?xid=166496004979787600&xp=48',
#  'https://www.naukri.com/recruiters/rohitkumar-3277680?xid=166496004979787600&xp=49',
#  'https://www.naukri.com/recruiters/amirchowdhury-2925314?xid=166496004979787600&xp=50']

# %%
#Scraping Location
l1=[]
loc=[]
for i in url1:
    driver.get(i)
    g=driver.find_elements(By.XPATH,"//a[@class='fl ellipsis widLrg']")
    for i in g:
        l1.append(i.text)

# %%
loc=l1[1::2]

# %%
#Creating Dataframe
data=pd.DataFrame({"Name":name,"Company":company,"Designation":des,"Skills":skill,"Location":loc})
data
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Mahesh Babu Channa
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Vaishnavi Kudalkar
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                                  Azahar Shaikh
# 27                                          Manas
# 28                                          kumar
# 29                                   Sunil Vedula
# 30                                    Rajat Kumar
# 31                                Dhruv Dev Dubey
# 32                                      Jayanth N
# 33                                         Avodha
# 34                                       SREEDHAR
# 35                                    Priya Khare
# 36                                    Amit Sharma
# 37                                          Kanan
# 38                           Shashikant Chaudhary
# 39                                           Brad
# 40                                   Rutuja Pawar
# 41                            Madhusudhan Sridhar
# 42                                    Ankit Sinha
# 43                                 Gaurav Chouhan
# 44                                   Rashi Kacker
# 45                                        Ashwini
# 46                                   Balaji Kolli
# 47                                 Rajani Nagaraj
# 48                                    ROHIT Kumar
# 49                                 Amir Chowdhury
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                               SocialPrachar.com
# 11                   Infinitive Software Solutions
# 12                              Innominds Software
# 13                                        MoneyTap
# 14              QuantMagnum Technologies Pvt. Ltd.
# 15                             Codeachive learning
# 16                                  BISP Solutions
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                 NEAL ANALYTICS SERVICES PVT LTD
# 27      Autumn Leaf Consulting Services Private...
# 28                                         trainin
# 29                            Nanoprecise Sci Corp
# 30                  R.S Consultancy &amp; Services
# 31                                    Confidential
# 32        Dollarbird Information Services Pvt, Ltd
# 33                              Nikitha Palaparthi
# 34     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 35                          Independent Consultant
# 36                                 ASCO consulting
# 37                                         NY INST
# 38  3D India Staffing Research &amp; Consulting...
# 39                                     O.C. Tanner
# 40                                   Demand Matrix
# 41                             MADHUSUDHAN SRIDHAR
# 42                                  Suntech Global
# 43                        Strategic Consulting Lab
# 44                            Impel Labs Pvt. Ltd.
# 45                                    MRP Advisers
# 46                   Saras Solutions India Pvt Ltd
# 47                                     WildJasmine
# 48                             LNT Private Limited
# 49                                     Granular.ai
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                         HR Team Lead
# 11                           HR Manager
# 12                     Executive Hiring
# 13                           Company HR
# 14                           Company HR
# 15                         HR Executive
# 16                           HR Manager
# 17                 Assistant Manager HR
# 18  Senior Executive Talent Acquisition
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24                         HR Recruiter
# 25              Manager Human Resources
# 26                    Company Recruiter
# 27              Lead Talent acquisition
# 28                           Proprietor
# 29                                  CEO
# 30                          Founder CEO
# 31             Company Recruitment Head
# 32                      Project Manager
# 33       Business Development Associate
# 34               Recruitment Consultant
# 35                       Senior Manager
# 36                           Consultant
# 37         senior technology instructor
# 38             HR Recruiter/HR Excutive
# 39        Manager, Technical Recruiting
# 40                  Technical Recruiter
# 41                      Erp Implementer
# 42                       Head Analytics
# 43              Chief Technical Officer
# 44                   Sr Product Manager
# 45             Director Global Delivery
# 46                           Co Founder
# 47                           HR Manager
# 48                            Architect
# 49                     Managing Partner
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Social Media, digital media maketing, seo, smm...
# 11  Oracle Dba, Data Science, Data Warehousing, ET...
# 12  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 13  Business Intelligence, Data Warehousing, Data ...
# 14  Office Administration, Hr Administration, tele...
# 15               Data Science, Python, Data Analytics
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Data Science, Artificial Intelligence, Machine...
# 27  Software Architecture, Vp Engineering, Product...
# 28  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 29  Signal Processing, Machine Learning, Neural Ne...
# 30  Web Technologies, Project Management, Software...
# 31  Server Administartion, Verilog, Vhdl, Digital ...
# 32  Data Analytics, Managed Services, Team Leading...
# 33  Ethical Hacking, Security Operations Center, S...
# 34  Data Science, Machine Learning, Big Data Analy...
# 35  Data Science, Artificial Intelligence, analyti...
# 36  Machine Learning, Artificial Intelligence, Dat...
# 37  C, C++, Artificial Intelligence, Python, Php, ...
# 38  Relationship Management, Retail Sales, Private...
# 39                 Data Science, Software Engineering
# 40  Data Science, Big Data Analytics, Digital Mark...
# 41                  Data Science, Recruitment, Salary
# 42  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 43  Software Development, Business Intelligence, B...
# 44                   Data Science, Node.js, Angularjs
# 45  Data Science, Media Marketing, Resource Planni...
# 46  Data Analysis, Learning, Data Science, Compute...
# 47  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 48  Software Development, Core Java, Unit Testing,...
# 49  Machine Learning, Data Science, Product Manage...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10  Hyderabad / Secunderabad
# 11                 Hyderabad
# 12  Hyderabad / Secunderabad
# 13     Bengaluru / Bangalore
# 14                    Mumbai
# 15                    Mumbai
# 16                    Bhopal
# 17                Chandigarh
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26                      Pune
# 27     Bengaluru / Bangalore
# 28     Bengaluru / Bangalore
# 29                    Others
# 30                     Delhi
# 31     Bengaluru / Bangalore
# 32           Mysoru / Mysore
# 33  Hyderabad / Secunderabad
# 34  Hyderabad / Secunderabad
# 35     Bengaluru / Bangalore
# 36                 New Delhi
# 37                   Chennai
# 38                   Aligarh
# 39            Salt Lake City
# 40                      Pune
# 41     Bengaluru / Bangalore
# 42                    Mumbai
# 43                    Indore
# 44     Bengaluru / Bangalore
# 45                    MYSORE
# 46  Hyderabad / Secunderabad
# 47     Bengaluru / Bangalore
# 48                    Mumbai
# 49

# %%
driver.close()

# %% [markdown]
# # Q8

# %%
# connect to webdriver
driver = webdriver.Chrome("chromedriver.exe")

# get webpage
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#Creating empty list
Bookname = []
Authorname = []
Volumessold = []
Publisher = []
Genre = []

# %%
#scraping book names data
for i in driver.find_elements(By.XPATH,"//tbody//tr/td[2]"):
    Bookname.append(i.text)
    
#Scraping author names data
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Authorname.append(i.text)
    except NoSuchElementException:
        Authorname.append('-')
time.sleep(1)

#Scraping data of volumes sold
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[4]"):
    Volumessold.append(i.text)
    
#Scraping data of publisher names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[5]"):
    Publisher.append(i.text)
    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[6]"):
    Genre.append(i.text)

# %%
#Creating dataframe for scraped data
Novels=pd.DataFrame({})
Novels['Book Name'] = Bookname
Novels['Author'] = Authorname
Novels['Volume sold'] = Volumessold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# # Q9

# %%
# connect to webdriver
driver = webdriver.Chrome("chromedriver.exe")
# get webpage
driver.get("https://www.imdb.com/list/ls095964455/")
driver.maximize_window()

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
#Scraping data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
#Scraping data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
#Scraping data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
#Scraping data of votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
TVseries=pd.DataFrame({})
TVseries['Name'] = Name
TVseries['Year Span'] = Year_span
TVseries['Genre'] = Genre
TVseries['Run Time'] = Run_time
TVseries['Ratings'] = Ratings
TVseries['Votes'] = Votes

# %%
TVseries
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,061,471
# 1    51 min     8.7  1,155,012
# 2    44 min     8.1    972,367
# 3    60 min     7.5    289,912
# 4    43 min     7.6    249,340
# ..      ...     ...        ...
# 95   42 min     7.4     49,692
# 96   50 min     7.8     60,744
# 97   42 min     8.1    195,525
# 98   45 min     7.1     41,154
# 99  572 min     8.6    238,154
#
# [100 rows x 6 columns]

# %%
driver.close()

# %% [markdown]
# # Q10

# %%
driver = webdriver.Chrome("chromedriver.exe")
# get webpage
driver.get(" https://archive.ics.uci.edu/")

# %%
# Finding view all dataset button from the webpage
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")    
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)

# %%
# Fetching page urls of all datasets 
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
list_url = view_list.get_attribute("href")           
driver.get(list_url)

# %%
# Fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")    

urls = []     
for i in dataset_url:
    urls.append(i.get_attribute("href"))

# %%
#Creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

# %%
for i in urls:
    driver.get(i)
    time.sleep(2)
    
    #Scraping Dataset name
    try: 
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    
    
    #Scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    
    #scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    
    
    # Scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    
    
    # Scraping No of instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
        
          # Scraping No of attributes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
        
      
    # Scraping year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')

# %%
ML=pd.DataFrame({})
ML['Data Name'] = Dataset_name[:622]
ML['Data Type'] = Data_type[:622]
ML['Task'] = Task[:622]
ML['Attribute type'] = Attribute_type[:622]
ML['No of instance'] = No_of_instances[:622]
ML['No of attributes'] = No_of_attributes[:622]
ML['Year'] = Year[:622]

# %%
ML
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# 4                 Multivariate  Classification, Clustering
# ..                         ...                         ...
# 617         Multivariate, Text              Classification
# 618         Multivariate, Text  Classification, Clustering
# 619                       Text              Classification
# 620                          -              Classification
# 621               Multivariate              Classification
#
#            Attribute type No of instance No of attributes  Year
# 0                    Real           7840                5  2018
# 1                    Real         434874                4  2013
# 2           Integer, Real           1984                8  2019
# 3                    Real         158716                4  2021
# 4                       -            232               16  2020
# ..                    ...            ...              ...   ...
# 617                     -           9800                3  2019
# 618         Integer, Real         120000          1000000  2013
# 619                     -           1956                5  2017
# 620         Integer, Real            303               56  2017
# 621  Categorical, Integer            101               17  1990
#
# [622 rows x 7 columns]

# %%
driver.close()
